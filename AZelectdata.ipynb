# %%
import pandas as pd

# %%
import urllib.request

user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

url = "https://recorder.maricopa.gov/media/ArizonaExportByPrecinct_110320.txt"
headers={'User-Agent':user_agent,} 

request=urllib.request.Request(url,None,headers) #The assembled request
response = urllib.request.urlopen(request)
res = response.read() # The data u need

# %%
with open('data-text-file.txt','wb') as f:
    f.write(res)

# %%
df = pd.read_csv('data-text-file.txt',delimiter='\t')
# Out:
#         ContestId  ContestExtId            ContestName  \
# 0               1           NaN  Presidential Electors
# 1               1           NaN  Presidential Electors
# 2               1           NaN  Presidential Electors
# 3               1           NaN  Presidential Electors
# 4               1           NaN  Presidential Electors
# ...           ...           ...                    ...
# 155017        220           NaN        PROPOSITION 208
# 155018        220           NaN        PROPOSITION 208
# 155019        220           NaN        PROPOSITION 208
# 155020        220           NaN        PROPOSITION 208
# 155021        220           NaN        PROPOSITION 208
#
#         ContestPartyAffiliation  ContestVoteFor ContestType  ContestOrder  \
# 0                           NaN               1   Candidacy             1
# 1                           NaN               1   Candidacy             1
# 2                           NaN               1   Candidacy             1
# ...

# %%
type(res)
# Out:
# bytes

# %%
results = res.decode(encoding='utf-8')

# %%
data = results.split()

# %%
data
# Out:
# ['\ufeffContestId',
#  'ContestExtId',
#  'ContestName',
#  'ContestPartyAffiliation',
#  'ContestVoteFor',
#  'ContestType',
#  'ContestOrder',
#  'PrecinctId',
#  'PrecinctExtId',
#  'PrecinctName',
#  'PrecinctOrder',
#  'PrecinctStatus',
#  'PrecinctRegistered',
#  'PrecinctTurnout',
#  'PrecinctTurnoutPerc',
#  'CandidateId',
#  'CandidateExtId',
#  'CandidateName',
#  'CandidateType',
#  'CandidateAffiliation',
#  'CandidateOrder',
#  'Registered',
#  'Turnout',
#  'TurnoutPerc',
#  'Overvotes',
#  'Undervotes',
#  'Votes',
#  'Turnout_EARLY',
#  'VOTE',
#  'Overvotes_EARLY',
#  'VOTE',
#  'Undervotes_EARLY',
#  'VOTE',
#  'Votes_EARLY',
#  'VOTE',
#  'Turnout_ELECTION',
#  'DAY',
#  'Overvotes_ELECTION',
#  'DAY',
#  'Undervotes_ELECTION',
#  'DAY',
#  'Votes_ELECTION',
#  'DAY',
#  'Turnout_PROVISIONAL',
#  'Overvotes_PROVISIONAL',
#  'Undervotes_PROVISIONAL',
#  'Votes_PROVISIONAL',
#  '1',
#  'Presidential',
#  'Electors',
#  '1',
#  'Candidacy',
#  '1',
#  '1',
#  '1',
# ...

# %%
arr = np_array = np.array(data)

# %%
data.flatten()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-501ad9c53161> in <module>
# ----> 1 data.flatten()
#
# AttributeError: 'list' object has no attribute 'flatten'

# %%
cols = ['ContestId',
 'ContestExtId',
 'ContestName',
 'ContestPartyAffiliation',
 'ContestVoteFor',
 'ContestType',
 'ContestOrder',
 'PrecinctId',
 'PrecinctExtId',
 'PrecinctName',
 'PrecinctOrder',
 'PrecinctStatus',
 'PrecinctRegistered',
 'PrecinctTurnout',
 'PrecinctTurnoutPerc',
 'CandidateId',
 'CandidateExtId',
 'CandidateName',
 'CandidateType',
 'CandidateAffiliation',
 'CandidateOrder',
 'Registered',
 'Turnout',
 'TurnoutPerc',
 'Overvotes',
 'Undervotes',
 'Votes',
 'Turnout_EARLY',
 'VOTE',
 'Overvotes_EARLY',
 'VOTE',
 'Undervotes_EARLY',
 'VOTE',
 'Votes_EARLY',
 'VOTE',
 'Turnout_ELECTION',
 'DAY',
 'Overvotes_ELECTION',
 'DAY',
 'Undervotes_ELECTION',
 'DAY',
 'Votes_ELECTION',
 'DAY',
 'Turnout_PROVISIONAL',
 'Overvotes_PROVISIONAL',
 'Undervotes_PROVISIONAL',
 'Votes_PROVISIONAL']
